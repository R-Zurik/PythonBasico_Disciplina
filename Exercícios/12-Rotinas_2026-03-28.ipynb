# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Cite três vantagens do uso das funções e duas características que toda função deva ter?

# %% [markdown]
# R.: \
# A primeira vantagem é a de processamento. Deve-se por não ter que, toda vez que rodar o código, recorrer linha por linha (como em construções com "if" e "while). Será processada uma única linha contendo a função, mesmo que para esta ser estabelecida inicialmente tenha-se usado mais de uma. \
# A segunda vantagem é a de correção. Ao invés de ter que corrigir o erro ou alteração desejada em todas as linhas e células equivalentes (na situação sem função), basta alterar a definição da função para que todas as instâncias em que a função foi utilizada tenha o resultado alterado (1 correção ao invés de correções linha a linha). \
# A terceira vantagem é a de usabilidade, em que a função pode ser reutilizada diversas vezes sem a necessidade de escrever separadamente aquilo que deseja ser feito toda vez. Com isso, além de evitar várias repetições de código, auxilia em mantê-lo organizado e legível.
#
# Duas características que toda função deve ter é a palavra "def", a qual define e indica o que vai ser escrito é uma função; e o nome da função a ser utilizado, funcionando como identificador que permitirá executar o que está escrito dentro da função toda vez que esta for chamada por meio deste.

# %% [markdown]
# ## Responda a pergunta do exercício 2 da aula 10, usando funções:<br>
# Instancie um objeto da classe NumPy array, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.<br><br>
# Quantos e quais são os valores superiores a 10?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: <br>
# Começará definindo a função para identificar quantos e quais valores de um array são superiores a 10. Deve-se, portanto, começar com a palavra-chave que indica a definição de uma função (def), seguida do nome da função em si e parênteses. Dentro dos parênteses, definirá os parâmetros que a função poderá receber. Um destes, será o objeto a ser analisado em si, definindo que este têm que ser da classe numpy array (obj:np.ndarray); e o outro o valor superior para comparação, que pode ser da classe inteiro ou float (sup: int | float). Colocará também que está função retornará nada (-> None), pois se têm o intuito de retornar o resultado na função por meio do método print(). <br>
# Após essas definições gerais, colocará o que a função em si deve fazer. A função necessitará instanciar um objeto "z" da classe lista onde armazenará os valores que são superiores. Precisará também de um loop para avaliar valor por valor dentro do array e de uma condicional para ver se este valor é ou não superior. Uma possibilidade é utilizar for em conjunto com in, para que analise cada valor (x) existente no objeto array, um por um (for x in objeto array). Em seguida, deverá executar uma condicional com if verificando se este valor x é superior ao parâmetro determinado ao executar a função (sup). Se a condicional for verdadeira, deverá adicionar esse valor x na lista z criada anteriormente na função usando .append(). A função não precisará fazer nada caso o valor seja igual ou inferior, apenas devendo prosseguir para o próximo valor. Sendo assim, não precisará definir else. Após executar o loop completo, a função deverá imprimir (com print()) os resultados de quais (retornar o próprio objeto z da classe lista) e quantos (retornar o tamanho do objeto z com o método len()) valores são superiores. Como mencionado, uma vez que utilizará o método print() para retornar o resultado, definirá que esta função retornará nada. <br>
# Após definir a função, será instanciado em outra célula o objeto a ser analisado. Iniciará definindo uma seed para garantir a reprodutibilidade do resultado. Em sequência, deve-se gerar o objeto randômico da classe array de maneira a ter uma distribuição normal de média 10, desvio padrão 3 e 5 valores quantitativos ao todo. Para tal, instanciará um objeto resultante do método np.random.normal() com base nestas condições definidas. Para finalizar, basta executar a função com os parâmetros do objeto a ser analisado (obj = a função array randômica gerada) e qual valor superior deseja verificar (sup = 10).

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/Fluxograma03_12.png" width="400" />

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
# Função gerada:
def identificar_sup(obj:np.ndarray, sup:int | float) -> None:
    maiores = []
    for x in obj:
        if x > sup:
            maiores.append(float(x))
    print("Quais valores são superiores a", sup, ":\n",
          maiores, "\n\n",
          "Quantos valores são superiores a", sup, ":\n",
          len(maiores))
    return None

# %%
# Array gerado:
np.random.seed(42)
array_normal = np.random.normal(10, 3, 5)

# Função executada:
identificar_sup(obj = array_normal, sup = 10)
# Out:
# Quais valores são superiores a 10 :
#  [11.490142459033699, 11.943065614302078, 14.569089569224076]
#
#  Quantos valores são superiores a 10 :
#  3

# %%
# Mostrando o array gerado
print("Array gerado:", "\n", array_normal)
# Out:
# Array gerado:
#  [11.49014246  9.5852071  11.94306561 14.56908957  9.29753988]

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %%
identificar_sup(obj = array_normal, sup = 20)
# Out:
# Quais valores são superiores a 20 :
#  []
#
#  Quantos valores são superiores a 20 :
#  0

# %% [markdown]
# Como mostrado no código anterior, sim, seria possível. Não houve a determinação de objeto e valor superior fixos nas condições de "if" e iteração com "for", de maneira a não limitar a função a apenas estes. No lugar, colocou obj (que recebe qualquer objeto da classe numpy array que se deseja avaliar) e sup (que recebe qualquer valor inteiro ou float que se deseja utilizar como delimitador de números superiores). Sendo assim, necessita-se apenas inserir e identificar o objeto a ser analisado (respeitando a classe estipulada na função) e o número superior de escolha entre os parênteses da função.

# %% [markdown]
# ## Desenvolva um programa de computador que retorne a média de um conjunto de valores.

# %% [markdown]
# ## 06 – Descreva o racional da sua resposta:

# %% [markdown]
# R.:

# %% [markdown]
# ## 07 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ## 08 – Escreva o programa em Python:

# %%
# Função gerada:
def identificar_media(obj:np.ndarray | list | tuple) -> float:
    n = 0
    media = []
    while n < len(obj):
        media.append(obj[n])
        n = n+1
    media = np.array(media)
    media = float(media.sum()/n)
    return media

# %%
# Conferindo a função:
    # Com array
np.random.seed(42)
array_normal = np.random.normal(10, 3, 5)

print(identificar_media(obj = array_normal)) # Executando função

    # Com lista
lista_teste = [0, 10, 20, 30, 40, 50]
print(identificar_media(obj = lista_teste))

    # Com tupla
tupla_teste = (0, 20, 40, 60, 80, 100)
print(identificar_media(obj = tupla_teste))
# Out:
# 11.377008922975257
# 25.0
# 50.0

# %% [markdown]
# ## 09 – Desenvolva um programa de computador que retorne a divisão de dois objetos simples. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def divisor_simples (obj_1: int | float, obj_2: int | float) -> float:
    if type(obj_1) == int or type(obj_1) == float:
        if type(obj_2) == int or type(obj_2) == float:
            resposta = obj_1/obj_2
        else:
            print("obj_1 é inteiro ou float, mas não obj_2")
    else:
        if type(obj_2) == int or type(obj_2) == float:
            print("obj_2 é inteiro ou float, mas não obj_2")
        else:
            print("Nenhum são inteiro ou float")
    return resposta


divisor_simples(obj_1=10, obj_2=2)
# Out:
# 5.0

# %% [markdown]
# ## 10 – Desenvolva um programa de computador que retorne a divisão de dois objetos compostos. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
# Definindo a função
def divisor_composto (obj_1: list | tuple, obj_2: list | tuple) -> list:
    tipos = (int, float)
    resposta = []
    for x in range(len(obj_1)):
        if type(obj_1[x]) in tipos:
            if type(obj_2[x]) in tipos:
                resposta.append(obj_1[x]/obj_2[x])
            else:
                print("Valor", x, "de obj_1 é inteiro ou float, mas não", x, "de obj_2")
        else:
            if type(obj_2[x]) in tipos:
                print("Valor", x, "de obj_2 é inteiro ou float, mas não", x, "de obj_1")
            else:
                print("Nenhum dos valores", x, "de obj_1 e obj_2 são inteiros ou float")
    return resposta

# %%
# Testando a função com diferentes valores
divisor_composto(obj_1=[30,"30","40",80,100,"200",200,4.2],
                 obj_2=[2,4,6,"10",10,"200",200,5.2])
# Out:
# Valor 1 de obj_2 é inteiro ou float, mas não 1 de obj_1
# Valor 2 de obj_2 é inteiro ou float, mas não 2 de obj_1
# Valor 3 de obj_1 é inteiro ou float, mas não 3 de obj_2
# Nenhum dos valores 5 de obj_1 e obj_2 são inteiros ou float
# [15.0, 10.0, 1.0, 0.8076923076923077]
